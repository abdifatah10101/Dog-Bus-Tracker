# %%
Bus_dic = {
    1: {"name": "Joe", "breed": 'Pitbull', 'pickup_time': '6:00 am', 'dropoff_time': '2:00 pm'},
    2: {"name": "John", "breed": 'Pitbull', 'pickup_time': '6:30 am', 'dropoff_time': '2:30 pm'},
    3: {"name": "Ryan", "breed": 'German Sheperd', 'pickup_time': '7:00 am', 'dropoff_time': '3:00 pm'},
    4: {"name": "Robert", "breed": 'German Sheperd', 'pickup_time': '7:30 am', 'dropoff_time': '3:30 pm'}
}

MAX_SEATS = 5

# %%
for seat in Bus_dic.keys():
    print("Seat", seat, Bus_dic[seat]['name'], Bus_dic[seat]['breed'], Bus_dic[seat]['pickup_time'])
# Out:
# Seat 1 Joe Pitbull 6:00 am
# Seat 2 John Pitbull 6:30 am
# Seat 3 Ryan German Sheperd 7:00 am
# Seat 4 Robert German Sheperd 7:30 am

# %%
Bus_dic.update({5: {"name": "Daniel", "breed": 'Pitbull', 'pickup_time': '8:00 am', 'dropoff_time': '4:00 pm'}})

# %%
for seat in Bus_dic.keys():
    print("Seat", seat, Bus_dic[seat]['name'], Bus_dic[seat]['breed'], Bus_dic[seat]['pickup_time'])
# Out:
# Seat 1 Joe Pitbull 6:00 am
# Seat 2 John Pitbull 6:30 am
# Seat 3 Ryan German Sheperd 7:00 am
# Seat 4 Robert German Sheperd 7:30 am
# Seat 5 Daniel Pitbull 8:00 am

# %%
Left = Bus_dic.pop(3)

# %%
print(Left['name'], "left the bus.")
# Out:
# Ryan left the bus.

# %%
for seat in Bus_dic.keys():
    print("Final Roster:", "Seat", seat, Bus_dic[seat]['name'], Bus_dic[seat]['breed'], Bus_dic[seat]['dropoff_time'])
# Out:
# Final Roster: Seat 1 Joe Pitbull 2:00 pm
# Final Roster: Seat 2 John Pitbull 2:30 pm
# Final Roster: Seat 4 Robert German Sheperd 3:30 pm
# Final Roster: Seat 5 Daniel Pitbull 4:00 pm
